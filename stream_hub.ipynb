# %%
import json

with open('/dbfs/FileStore/tables/iotconfig.json') as config_file:
  config = json.load(config_file)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
event_hub_conf = {
    'eventhubs.connectionString' : config['Endpoint']
}

stream_data = (spark 
    .readStream
    .format('eventhubs')
    .options(**event_hub_conf)
    .load()
)

activity_query = stream_data.writeStream.queryName("stream_data").format("memory").start()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
